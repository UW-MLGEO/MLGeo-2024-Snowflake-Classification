# %% [markdown]
# # Preparing AI-ready PHIPS Image Classification Data
# ##### This notebook reads in the clean versions of the P-3 aircraft met/nav and PHIPS ice crystal image datasets to create an AI-ready dataset that converts the .PNG images to numpy arrays and stores them into an xarray.Dataset, including meta data from the P-3 met/nav dataset for each labled image (e.g. P-3 geographic coordinates, temperature, altitude)

# %%
# Import necessary packages
import tarfile
import numpy as np
import pandas as pd
import os
import glob 
from PIL import Image
import io 
import xarray as xr

# %%
# Read in P-3 met/nav data for each flight

dates = ['2020-02-07', '2022-02-17', '2023-01-23', '2023-02-14'] # flight dates

for date in dates:
    datestr = date.replace('-', '')
    fname_p3 = glob.glob(f'/home/disk/meso-home/vgarcia1/PHIPS_classification/MLGEO2024_Snowflake_Classification/data/clean/{date}_P3_MetNav.nc')[0]

    globals()[f'p3_nav_{datestr}'] = xr.open_dataset(fname_p3)

    print(f'p3_nav_{datestr}')
    print(globals()[f'p3_nav_{datestr}'])
    print()
# Out:
# p3_nav_20200207
# <xarray.Dataset>
# Dimensions:      (time: 21359)
# Coordinates:
#   * time         (time) datetime64[ns] 2020-02-07T14:05:47 ... 2020-02-07T20:...
# Data variables: (12/35)
#     lon          (time) float64 ...
#     lat          (time) float64 ...
#     alt_gps      (time) float64 ...
#     alt_pres     (time) float64 ...
#     alt_radar    (time) float64 ...
#     grnd_spd     (time) float64 ...
#     ...           ...
#     svp_ice      (time) float64 ...
#     rh           (time) float64 ...
#     zenith       (time) float64 ...
#     sun_elev_P3  (time) float64 ...
#     sun_az       (time) float64 ...
#     sun_az_P3    (time) float64 ...
# Attributes: (12/27)
#     Experiment:           IMPACTS
#     Platform:             Wallops P-3 N426NA
#     Mission PI:           Lynn McMurdie (lynnm@uw.edu)
#     PI_CONTACT_INFO:      Melissa Yang Martin, m.yang@baeri.org
#     LOCATION:             Included in data records
#     ASSOCIATED_DATA:      This flight represents IMPACTS Science Flight #5 ou...
#     ...                   ...
#     PROJECT_INFO:         See IMPACTS site on ESPO website.
#     STIPULATIONS_ON_USE:  Please contact PI or DM with questions.
#     OTHER_COMMENTS:        Potential temperature derived from static air temp...
#     REVISION:             R0
#     R0:                   Calibrations applied to LN-251 EGI (true heading an...
#     RA:                   Preliminary field data with minimal QC. Limits of d...
#
# p3_nav_20220217
# <xarray.Dataset>
# Dimensions:      (time: 29478)
# Coordinates:
#   * time         (time) datetime64[ns] 2022-02-17T16:33:20 ... 2022-02-18T00:...
# Data variables: (12/35)
#     lon          (time) float64 ...
#     lat          (time) float64 ...
#     alt_gps      (time) float64 ...
#     alt_pres     (time) float64 ...
#     alt_radar    (time) float64 ...
#     grnd_spd     (time) float64 ...
#     ...           ...
#     svp_ice      (time) float64 ...
#     rh           (time) float64 ...
#     zenith       (time) float64 ...
#     sun_elev_P3  (time) float64 ...
#     sun_az       (time) float64 ...
#     sun_az_P3    (time) float64 ...
# Attributes: (12/27)
#     Experiment:           IMPACTS
#     Platform:             Wallops P-3 N426NA
#     Mission PI:           Lynn McMurdie (lynnm@uw.edu)
#     PI_CONTACT_INFO:      NSRC MetNav PI - Ryan Bennett - joseph.r.bennett@na...
#     LOCATION:             Included in data records
#     ASSOCIATED_DATA:      This flight represents IMPACTS Science flight #09 o...
#     ...                   ...
#     PROJECT_INFO:         For more information, please consult the project we...
#     STIPULATIONS_ON_USE:  Data users are strongly encouraged to consult the P...
#     OTHER_COMMENTS:        Potential temperature derived from static air temp...
#     REVISION:             R0
#     R0:                   Preliminary public release of the MetNav parameters...
#     RA:                   Preliminary field data with minimal QC. Limits of d...
#
# p3_nav_20230123
# <xarray.Dataset>
# Dimensions:      (time: 29095)
# Coordinates:
#   * time         (time) datetime64[ns] 2023-01-23T11:43:36 ... 2023-01-23T19:...
# Data variables: (12/35)
#     lon          (time) float64 ...
#     lat          (time) float64 ...
#     alt_gps      (time) float64 ...
#     alt_pres     (time) float64 ...
#     alt_radar    (time) float64 ...
#     grnd_spd     (time) float64 ...
#     ...           ...
#     svp_ice      (time) float64 ...
#     rh           (time) float64 ...
#     zenith       (time) float64 ...
#     sun_elev_P3  (time) float64 ...
#     sun_az       (time) float64 ...
#     sun_az_P3    (time) float64 ...
# Attributes: (12/27)
#     Experiment:           IMPACTS
#     Platform:             Wallops P-3 N426NA
#     Mission PI:           Lynn McMurdie (lynnm@uw.edu)
#     PI_CONTACT_INFO:      NSRC MetNav PI - Ryan Bennett - joseph.r.bennett@na...
#     LOCATION:             Included in data records
#     ASSOCIATED_DATA:      This flight represents IMPACTS science flight #04 o...
#     ...                   ...
#     PROJECT_INFO:         For more information, please consult the project we...
#     STIPULATIONS_ON_USE:  Data users are strongly encouraged to consult the P...
#     OTHER_COMMENTS:       Potential temperature derived from static air tempe...
#     REVISION:             R0
#     R0:                   Preliminary public release of the MetNav parameters...
#     RA:                   Preliminary field data with minimal QC. Limits of d...
#
# p3_nav_20230214
# <xarray.Dataset>
# Dimensions:      (time: 32007)
# Coordinates:
#   * time         (time) datetime64[ns] 2023-02-14T21:00:11 ... 2023-02-15T05:...
# Data variables: (12/35)
#     lon          (time) float64 ...
#     lat          (time) float64 ...
#     alt_gps      (time) float64 ...
#     alt_pres     (time) float64 ...
#     alt_radar    (time) float64 ...
#     grnd_spd     (time) float64 ...
#     ...           ...
#     svp_ice      (time) float64 ...
#     rh           (time) float64 ...
#     zenith       (time) float64 ...
#     sun_elev_P3  (time) float64 ...
#     sun_az       (time) float64 ...
#     sun_az_P3    (time) float64 ...
# Attributes: (12/27)
#     Experiment:           IMPACTS
#     Platform:             Wallops P-3 N426NA
#     Mission PI:           Lynn McMurdie (lynnm@uw.edu)
#     PI_CONTACT_INFO:      NSRC MetNav PI - Ryan Bennett - joseph.r.bennett@na...
#     LOCATION:             Included in data records
#     ASSOCIATED_DATA:      This flight represents IMPACTS science flight #10 o...
#     ...                   ...
#     PROJECT_INFO:         For more information, please consult the project we...
#     STIPULATIONS_ON_USE:  Data users are strongly encouraged to consult the P...
#     OTHER_COMMENTS:       Potential temperature derived from static air tempe...
#     REVISION:             R0
#     R0:                   Preliminary public release of the MetNav parameters...
#     RA:                   Preliminary field data with minimal QC. Limits of d...

# %%
# List of ice crystal habit types with corresponding folder names
habits = {
    'aggregates': 'Aggregates', 'bullet_rosettes': 'Bullet-rosettes', 'capped_columns': 'Capped-columns', 
    'columns': 'Columns', 'dendrites': 'Dendrites', 'graupel': 'Graupel', 
    'needles': 'Needles', 'plates': 'Plates', 'polycrystals': 'Polycrystals', 
    'side_planes': 'Side-planes', 'tiny': 'Tiny'
}

# List of ice crystal habit types in singular form
habits_singular = ['aggregate', 'bullet_rosette', 'capped_column', 'column', 'dendrite', 'graupel', 'needle', 'plate', 'polycrystal', 'side_plane', 'tiny']

# Flight navigation datasets
nav_datasets = {
    "2020-02-07": p3_nav_20200207,
    "2022-02-17": p3_nav_20220217,
    "2023-01-23": p3_nav_20230123,
    "2023-02-14": p3_nav_20230214
}

# %%
# Define a list to hold the dataset entries
dataset_entries = []

# Loop through each habit type
for habit, folder_name in habits.items():
    tar_file = f'/home/disk/meso-home/vgarcia1/PHIPS_classification/MLGEO2024_Snowflake_Classification/data/clean/PHIPS_{habit}.tar.gz'  # Construct the tar.gz file name
    
    # Make label singular if necessary
    if habit == 'tiny' or habit == 'graupel':
        label = habit
    else:
        label = habit[:-1]  # Assign the label based on the habit type

    print(f"Extracting images for {habit}...")

    # Open the tar.gz file
    with tarfile.open(tar_file, "r:gz") as tar:
        for member in tar.getmembers():
            # Check if the member is a file and ends with .png
            if member.isfile() and member.name.lower().endswith(".png"):
                # Check if the file is inside the folder named according to the corresponding folder name
                if os.path.dirname(member.name).split('/')[-1] == folder_name:
                    print(member.name)
                    # Extract and read image data
                    file = tar.extractfile(member)
                    if file is not None:
                        image = Image.open(io.BytesIO(file.read()))
                        image_array = np.array(image)
                        
                        # Extract timestamp from the filename
                        parts = member.name.split('_')

                        date2 = parts[4][:8]  # Date of the flight
                        time2 = parts[4][8:]  # Time of the flight (HHMMSS format)

                        timestamp = f"{date2}T{time2[:2]}:{time2[2:4]}:{time2[4:]}"  # Convert to ISO format
                        
                        # Convert date2 to match the format in nav_datasets keys (YYYY-MM-DD)
                        date2_formatted = f"{date2[:4]}-{date2[4:6]}-{date2[6:]}"

                        # Match the date with the appropriate navigation dataset
                        nav_data = nav_datasets.get(date2_formatted)

                        # Extract lat, lon, and temperature from the nav data if available
                        if nav_data is not None:
                            # Correct the timestamp format to "YYYY-MM-DDTHH:MM:SS"
                            timestamp = f"{date2[:4]}-{date2[4:6]}-{date2[6:]}T{time2[:2]}:{time2[2:4]}:{time2[4:]}"
                            time = np.datetime64(timestamp)
                            
                            # Print the timestamp from the image filename
                            print("Timestamp of the image:", timestamp)
                            
                            # Get the time values from nav_data
                            nav_time = nav_data['time'].values  # Assuming time is an array in nav_data

                            # Convert nav_time to np.datetime64 if necessary
                            if not np.issubdtype(nav_time.dtype, np.datetime64):
                                print("Converting nav_time to np.datetime64")
                                nav_time = nav_time.astype('datetime64[s]')

                            # Find the nearest time index
                            nearest_time_idx = np.abs(nav_time - time).argmin()

                            # Print the timestamp from the nav_data
                            print("Timestamp from nav_data:", nav_data.time[nearest_time_idx].values)

                            # Extract latitude, longitude, and temperature
                            lat = nav_data['lat'].isel(time=nearest_time_idx).values
                            lon = nav_data['lat'].isel(time=nearest_time_idx).values
                            temperature = np.round(nav_data['temp'].isel(time=nearest_time_idx).values, 3)
                            altitude = np.round(nav_data['alt_gps'].isel(time=nearest_time_idx).values/1000, 3) # Convert to km
                        else:
                            lat = np.nan
                            lon = np.nan
                            temperature = np.nan
                            altitude = np.nan
                        
                        # Create a dictionary for this entry
                        dataset_entry = { 
                            "image_array": image_array,
                            "timestamp": timestamp,
                            'label': label,  # Use singular label from the mapping
                            "latitude": lat,
                            "longitude": lon,
                            "temperature": temperature,
                            "altitude": altitude
                        }

                        # Print dimensions of the image array
                        print("Image array shape:", image_array.shape)
                        print()


                        dataset_entries.append(dataset_entry)
# Out:
# Extracting images for aggregates...
# Aggregates/IMPACTS_PHIPS_20200207_1347_20200207151036_003174_C1.png
# Timestamp of the image: 2020-02-07T15:10:36
# Timestamp from nav_data: 2020-02-07T15:10:36.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20200207_1347_20200207151037_003177_C1.png
# Timestamp of the image: 2020-02-07T15:10:37
# Timestamp from nav_data: 2020-02-07T15:10:37.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20200207_1347_20200207151039_003183_C1.png
# Timestamp of the image: 2020-02-07T15:10:39
# Timestamp from nav_data: 2020-02-07T15:10:39.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20200207_1347_20200207151040_003184_C1.png
# Timestamp of the image: 2020-02-07T15:10:40
# Timestamp from nav_data: 2020-02-07T15:10:40.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20200207_1347_20200207151040_003185_C1.png
# Timestamp of the image: 2020-02-07T15:10:40
# Timestamp from nav_data: 2020-02-07T15:10:40.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20200207_1347_20200207151044_003197_C1.png
# Timestamp of the image: 2020-02-07T15:10:44
# Timestamp from nav_data: 2020-02-07T15:10:44.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20200207_1347_20200207151052_003219_C1.png
# Timestamp of the image: 2020-02-07T15:10:52
# Timestamp from nav_data: 2020-02-07T15:10:52.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20200207_1347_20200207151118_003290_C1.png
# Timestamp of the image: 2020-02-07T15:11:18
# Timestamp from nav_data: 2020-02-07T15:11:18.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20200207_1347_20200207151120_003297_C1.png
# Timestamp of the image: 2020-02-07T15:11:20
# Timestamp from nav_data: 2020-02-07T15:11:20.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20200207_1347_20200207151128_003319_C1.png
# Timestamp of the image: 2020-02-07T15:11:28
# Timestamp from nav_data: 2020-02-07T15:11:28.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20200207_1347_20200207151228_003485_C1.png
# Timestamp of the image: 2020-02-07T15:12:28
# Timestamp from nav_data: 2020-02-07T15:12:28.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20200207_1347_20200207151926_004552_C1.png
# Timestamp of the image: 2020-02-07T15:19:26
# Timestamp from nav_data: 2020-02-07T15:19:26.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20200207_1347_20200207152432_005271_C1.png
# Timestamp of the image: 2020-02-07T15:24:32
# Timestamp from nav_data: 2020-02-07T15:24:32.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20220217_1532_20220217194933_002784_C1.png
# Timestamp of the image: 2022-02-17T19:49:33
# Timestamp from nav_data: 2022-02-17T19:49:33.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20220217_1532_20220217195004_002797_C1.png
# Timestamp of the image: 2022-02-17T19:50:04
# Timestamp from nav_data: 2022-02-17T19:50:04.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20220217_1532_20220217195024_002804_C1.png
# Timestamp of the image: 2022-02-17T19:50:24
# Timestamp from nav_data: 2022-02-17T19:50:24.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20230214_2105_20230215001756_007416_C1.png
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20200207_1347_20200207151254_003556_C1.png
# Timestamp of the image: 2020-02-07T15:12:54
# Timestamp from nav_data: 2020-02-07T15:12:54.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20230123_1240_20230123140559_001388_C1.png
# Timestamp of the image: 2023-01-23T14:05:59
# Timestamp from nav_data: 2023-01-23T14:05:59.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20230123_1408_20230123144217_001513_C1.png
# Timestamp of the image: 2023-01-23T14:42:17
# Timestamp from nav_data: 2023-01-23T14:42:17.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20230123_1408_20230123144255_001638_C1.png
# Timestamp of the image: 2023-01-23T14:42:55
# Timestamp from nav_data: 2023-01-23T14:42:55.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20230123_1408_20230123144259_001652_C1.png
# Timestamp of the image: 2023-01-23T14:42:59
# Timestamp from nav_data: 2023-01-23T14:42:59.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20230123_1408_20230123174806_012373_C1.png
# Timestamp of the image: 2023-01-23T17:48:06
# Timestamp from nav_data: 2023-01-23T17:48:06.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20220217_1532_20220217211716_004962_C1.png
# Timestamp of the image: 2022-02-17T21:17:16
# Timestamp from nav_data: 2022-02-17T21:17:16.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20220217_1532_20220217211731_004968_C1.png
# Timestamp of the image: 2022-02-17T21:17:31
# Timestamp from nav_data: 2022-02-17T21:17:31.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20220217_1532_20220217211805_004976_C1.png
# Timestamp of the image: 2022-02-17T21:18:05
# Timestamp from nav_data: 2022-02-17T21:18:05.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20230214_2105_20230215010623_009005_C1.png
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20230214_2105_20230215010625_009008_C1.png
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20230214_2105_20230215013035_010059_C1.png
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20230123_1408_20230123165836_010014_C1.png
# Timestamp of the image: 2023-01-23T16:58:36
# Timestamp from nav_data: 2023-01-23T16:58:36.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20230123_1408_20230123165838_010017_C1.png
# Timestamp of the image: 2023-01-23T16:58:38
# Timestamp from nav_data: 2023-01-23T16:58:38.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20230123_1408_20230123165905_010073_C1.png
# Timestamp of the image: 2023-01-23T16:59:05
# Timestamp from nav_data: 2023-01-23T16:59:05.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20230123_1408_20230123170108_010228_C1.png
# Timestamp of the image: 2023-01-23T17:01:08
# Timestamp from nav_data: 2023-01-23T17:01:08.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20230123_1408_20230123170350_010485_C1.png
# Timestamp of the image: 2023-01-23T17:03:50
# Timestamp from nav_data: 2023-01-23T17:03:50.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20230123_1408_20230123170404_010519_C1.png
# Timestamp of the image: 2023-01-23T17:04:04
# Timestamp from nav_data: 2023-01-23T17:04:04.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20230123_1408_20230123170414_010539_C1.png
# Timestamp of the image: 2023-01-23T17:04:14
# Timestamp from nav_data: 2023-01-23T17:04:14.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20230123_1408_20230123170423_010551_C1.png
# Timestamp of the image: 2023-01-23T17:04:23
# Timestamp from nav_data: 2023-01-23T17:04:23.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20230123_1408_20230123170430_010561_C1.png
# Timestamp of the image: 2023-01-23T17:04:30
# Timestamp from nav_data: 2023-01-23T17:04:30.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20230123_1408_20230123170431_010562_C1.png
# Timestamp of the image: 2023-01-23T17:04:31
# Timestamp from nav_data: 2023-01-23T17:04:31.000000000
# Image array shape: (1024, 1360)
#
# Aggregates/IMPACTS_PHIPS_20230123_1408_20230123173428_011673_C1.png
# Timestamp of the image: 2023-01-23T17:34:28
# Timestamp from nav_data: 2023-01-23T17:34:28.000000000
# Image array shape: (1024, 1360)
#
# Extracting images for bullet_rosettes...
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215004512_008147_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215004551_008164_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215004552_008165_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215004707_008174_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215004808_008189_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215005403_008370_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215005405_008371_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215005427_008393_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215005453_008417_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215005802_008573_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215004127_008027_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215011624_009463_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215011658_009478_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215011730_009491_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215020330_011389_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215020529_011455_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215021409_011671_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215021437_011679_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215021504_011684_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215021552_011701_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215021828_011723_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215022243_011743_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215022247_011744_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215022256_011745_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215022434_011752_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215022536_011754_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215022644_011762_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215022816_011794_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215022845_011802_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215023322_011936_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215023524_011964_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215024237_012046_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215024257_012054_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215024435_012083_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215024521_012095_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215025059_012232_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215025529_012401_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215025728_012428_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215025218_012286_C1.png
# Image array shape: (1024, 1360)
#
# Bullet-rosettes/IMPACTS_PHIPS_20230214_2105_20230215025145_012261_C1.png
# Image array shape: (1024, 1360)
#
# Extracting images for capped_columns...
# Capped-columns/IMPACTS_PHIPS_20200207_1347_20200207152407_005205_C1.png
# Timestamp of the image: 2020-02-07T15:24:07
# Timestamp from nav_data: 2020-02-07T15:24:07.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20200207_1347_20200207152408_005206_C1.png
# Timestamp of the image: 2020-02-07T15:24:08
# Timestamp from nav_data: 2020-02-07T15:24:08.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20200207_1347_20200207152412_005217_C1.png
# Timestamp of the image: 2020-02-07T15:24:12
# Timestamp from nav_data: 2020-02-07T15:24:12.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20200207_1347_20200207152418_005234_C1.png
# Timestamp of the image: 2020-02-07T15:24:18
# Timestamp from nav_data: 2020-02-07T15:24:18.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20200207_1347_20200207152501_005335_C1.png
# Timestamp of the image: 2020-02-07T15:25:01
# Timestamp from nav_data: 2020-02-07T15:25:01.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20200207_1347_20200207152448_005311_C1.png
# Timestamp of the image: 2020-02-07T15:24:48
# Timestamp from nav_data: 2020-02-07T15:24:48.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20200207_1347_20200207152449_005313_C1.png
# Timestamp of the image: 2020-02-07T15:24:49
# Timestamp from nav_data: 2020-02-07T15:24:49.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20200207_1347_20200207152455_005326_C1.png
# Timestamp of the image: 2020-02-07T15:24:55
# Timestamp from nav_data: 2020-02-07T15:24:55.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20200207_1347_20200207152528_005389_C1.png
# Timestamp of the image: 2020-02-07T15:25:28
# Timestamp from nav_data: 2020-02-07T15:25:28.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20200207_1347_20200207152602_005469_C1.png
# Timestamp of the image: 2020-02-07T15:26:02
# Timestamp from nav_data: 2020-02-07T15:26:02.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20230123_1408_20230123174807_012376_C1.png
# Timestamp of the image: 2023-01-23T17:48:07
# Timestamp from nav_data: 2023-01-23T17:48:07.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20220217_1532_20220217201640_003380_C1.png
# Timestamp of the image: 2022-02-17T20:16:40
# Timestamp from nav_data: 2022-02-17T20:16:40.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20220217_1532_20220217202242_003549_C1.png
# Timestamp of the image: 2022-02-17T20:22:42
# Timestamp from nav_data: 2022-02-17T20:22:42.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20220217_1532_20220217204116_004023_C1.png
# Timestamp of the image: 2022-02-17T20:41:16
# Timestamp from nav_data: 2022-02-17T20:41:16.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20220217_1532_20220217213332_005406_C1.png
# Timestamp of the image: 2022-02-17T21:33:32
# Timestamp from nav_data: 2022-02-17T21:33:32.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20230214_2105_20230215011400_009393_C1.png
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20230214_2105_20230215012140_009679_C1.png
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20230214_2105_20230215012700_009925_C1.png
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20230214_2105_20230215013305_010142_C1.png
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20230214_2105_20230215014855_010771_C1.png
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20230123_1408_20230123173217_011417_C1.png
# Timestamp of the image: 2023-01-23T17:32:17
# Timestamp from nav_data: 2023-01-23T17:32:17.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20230123_1408_20230123173709_012059_C1.png
# Timestamp of the image: 2023-01-23T17:37:09
# Timestamp from nav_data: 2023-01-23T17:37:09.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20230123_1408_20230123173743_012175_C1.png
# Timestamp of the image: 2023-01-23T17:37:43
# Timestamp from nav_data: 2023-01-23T17:37:43.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20220217_1532_20220217202328_003572_C1.png
# Timestamp of the image: 2022-02-17T20:23:28
# Timestamp from nav_data: 2022-02-17T20:23:28.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20220217_1532_20220217202845_003793_C1.png
# Timestamp of the image: 2022-02-17T20:28:45
# Timestamp from nav_data: 2022-02-17T20:28:45.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20220217_1532_20220217212558_005209_C1.png
# Timestamp of the image: 2022-02-17T21:25:58
# Timestamp from nav_data: 2022-02-17T21:25:58.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20220217_1532_20220217213407_005422_C1.png
# Timestamp of the image: 2022-02-17T21:34:07
# Timestamp from nav_data: 2022-02-17T21:34:07.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20220217_1532_20220217213735_005525_C1.png
# Timestamp of the image: 2022-02-17T21:37:35
# Timestamp from nav_data: 2022-02-17T21:37:35.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20220217_1532_20220217213759_005543_C1.png
# Timestamp of the image: 2022-02-17T21:37:59
# Timestamp from nav_data: 2022-02-17T21:37:59.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20230123_1408_20230123142409_000576_C1.png
# Timestamp of the image: 2023-01-23T14:24:09
# Timestamp from nav_data: 2023-01-23T14:24:09.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20230123_1408_20230123142410_000581_C1.png
# Timestamp of the image: 2023-01-23T14:24:10
# Timestamp from nav_data: 2023-01-23T14:24:10.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20230123_1408_20230123142424_000628_C1.png
# Timestamp of the image: 2023-01-23T14:24:24
# Timestamp from nav_data: 2023-01-23T14:24:24.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20230123_1408_20230123142451_000697_C1.png
# Timestamp of the image: 2023-01-23T14:24:51
# Timestamp from nav_data: 2023-01-23T14:24:51.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20230123_1408_20230123142453_000704_C1.png
# Timestamp of the image: 2023-01-23T14:24:53
# Timestamp from nav_data: 2023-01-23T14:24:53.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20230214_2105_20230215020512_011444_C1.png
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20200207_1347_20200207152447_005307_C1.png
# Timestamp of the image: 2020-02-07T15:24:47
# Timestamp from nav_data: 2020-02-07T15:24:47.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20200207_1347_20200207152452_005321_C1.png
# Timestamp of the image: 2020-02-07T15:24:52
# Timestamp from nav_data: 2020-02-07T15:24:52.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20200207_1347_20200207152538_005409_C1.png
# Timestamp of the image: 2020-02-07T15:25:38
# Timestamp from nav_data: 2020-02-07T15:25:38.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20200207_1347_20200207152547_005431_C1.png
# Timestamp of the image: 2020-02-07T15:25:47
# Timestamp from nav_data: 2020-02-07T15:25:47.000000000
# Image array shape: (1024, 1360)
#
# Capped-columns/IMPACTS_PHIPS_20200207_1347_20200207152551_005442_C1.png
# Timestamp of the image: 2020-02-07T15:25:51
# Timestamp from nav_data: 2020-02-07T15:25:51.000000000
# Image array shape: (1024, 1360)
#
# Extracting images for columns...
# Columns/IMPACTS_PHIPS_20220217_1532_20220217165104_000032_C1.png
# Timestamp of the image: 2022-02-17T16:51:04
# Timestamp from nav_data: 2022-02-17T16:51:04.000000000
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20200207_1347_20200207152353_005166_C1.png
# Timestamp of the image: 2020-02-07T15:23:53
# Timestamp from nav_data: 2020-02-07T15:23:53.000000000
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20200207_1347_20200207152354_005168_C1.png
# Timestamp of the image: 2020-02-07T15:23:54
# Timestamp from nav_data: 2020-02-07T15:23:54.000000000
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20200207_1347_20200207152354_005169_C1.png
# Timestamp of the image: 2020-02-07T15:23:54
# Timestamp from nav_data: 2020-02-07T15:23:54.000000000
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20200207_1347_20200207152357_005178_C1.png
# Timestamp of the image: 2020-02-07T15:23:57
# Timestamp from nav_data: 2020-02-07T15:23:57.000000000
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20200207_1347_20200207152358_005180_C1.png
# Timestamp of the image: 2020-02-07T15:23:58
# Timestamp from nav_data: 2020-02-07T15:23:58.000000000
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20200207_1347_20200207152402_005191_C1.png
# Timestamp of the image: 2020-02-07T15:24:02
# Timestamp from nav_data: 2020-02-07T15:24:02.000000000
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20200207_1347_20200207152404_005196_C1.png
# Timestamp of the image: 2020-02-07T15:24:04
# Timestamp from nav_data: 2020-02-07T15:24:04.000000000
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20200207_1347_20200207152404_005197_C1.png
# Timestamp of the image: 2020-02-07T15:24:04
# Timestamp from nav_data: 2020-02-07T15:24:04.000000000
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20200207_1347_20200207152406_005202_C1.png
# Timestamp of the image: 2020-02-07T15:24:06
# Timestamp from nav_data: 2020-02-07T15:24:06.000000000
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20200207_1347_20200207152412_005219_C1.png
# Timestamp of the image: 2020-02-07T15:24:12
# Timestamp from nav_data: 2020-02-07T15:24:12.000000000
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20200207_1347_20200207152555_005451_C1.png
# Timestamp of the image: 2020-02-07T15:25:55
# Timestamp from nav_data: 2020-02-07T15:25:55.000000000
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20200207_1347_20200207152554_005450_C1.png
# Timestamp of the image: 2020-02-07T15:25:54
# Timestamp from nav_data: 2020-02-07T15:25:54.000000000
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20200207_1347_20200207152555_005452_C1.png
# Timestamp of the image: 2020-02-07T15:25:55
# Timestamp from nav_data: 2020-02-07T15:25:55.000000000
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20200207_1347_20200207152607_005485_C1.png
# Timestamp of the image: 2020-02-07T15:26:07
# Timestamp from nav_data: 2020-02-07T15:26:07.000000000
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20200207_1347_20200207152609_005492_C1.png
# Timestamp of the image: 2020-02-07T15:26:09
# Timestamp from nav_data: 2020-02-07T15:26:09.000000000
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20200207_1347_20200207152624_005532_C1.png
# Timestamp of the image: 2020-02-07T15:26:24
# Timestamp from nav_data: 2020-02-07T15:26:24.000000000
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20200207_1347_20200207152648_005596_C1.png
# Timestamp of the image: 2020-02-07T15:26:48
# Timestamp from nav_data: 2020-02-07T15:26:48.000000000
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20200207_1347_20200207152727_005680_C1.png
# Timestamp of the image: 2020-02-07T15:27:27
# Timestamp from nav_data: 2020-02-07T15:27:27.000000000
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20200207_1347_20200207153024_005835_C1.png
# Timestamp of the image: 2020-02-07T15:30:24
# Timestamp from nav_data: 2020-02-07T15:30:24.000000000
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20220217_1532_20220217192313_002283_C1.png
# Timestamp of the image: 2022-02-17T19:23:13
# Timestamp from nav_data: 2022-02-17T19:23:13.000000000
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20220217_1532_20220217192553_002343_C1.png
# Timestamp of the image: 2022-02-17T19:25:53
# Timestamp from nav_data: 2022-02-17T19:25:53.000000000
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20220217_1532_20220217192634_002366_C1.png
# Timestamp of the image: 2022-02-17T19:26:34
# Timestamp from nav_data: 2022-02-17T19:26:34.000000000
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20220217_1532_20220217192740_002397_C1.png
# Timestamp of the image: 2022-02-17T19:27:40
# Timestamp from nav_data: 2022-02-17T19:27:40.000000000
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20220217_1532_20220217194228_002632_C1.png
# Timestamp of the image: 2022-02-17T19:42:28
# Timestamp from nav_data: 2022-02-17T19:42:28.000000000
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20220217_1532_20220217204208_004046_C1.png
# Timestamp of the image: 2022-02-17T20:42:08
# Timestamp from nav_data: 2022-02-17T20:42:08.000000000
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20220217_1532_20220218000546_007539_C1.png
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20230214_2105_20230215004127_008028_C1.png
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20230214_2105_20230215010143_008720_C1.png
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20230214_2105_20230215011725_009487_C1.png
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20230214_2105_20230215021500_011681_C1.png
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20230214_2105_20230215022203_011738_C1.png
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20230214_2105_20230215022243_011742_C1.png
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20230214_2105_20230215022425_011751_C1.png
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20230214_2105_20230215022903_011809_C1.png
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20230214_2105_20230215024634_012119_C1.png
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20230214_2105_20230215024847_012175_C1.png
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20230214_2105_20230215025455_012390_C1.png
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20220217_1532_20220217201411_003308_C1.png
# Timestamp of the image: 2022-02-17T20:14:11
# Timestamp from nav_data: 2022-02-17T20:14:11.000000000
# Image array shape: (1024, 1360)
#
# Columns/IMPACTS_PHIPS_20220217_1532_20220217203335_003874_C1.png
# Timestamp of the image: 2022-02-17T20:33:35
# Timestamp from nav_data: 2022-02-17T20:33:35.000000000
# Image array shape: (1024, 1360)
#
# Extracting images for dendrites...
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207151140_003351_C1.png
# Timestamp of the image: 2020-02-07T15:11:40
# Timestamp from nav_data: 2020-02-07T15:11:40.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207151159_003407_C1.png
# Timestamp of the image: 2020-02-07T15:11:59
# Timestamp from nav_data: 2020-02-07T15:11:59.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207151220_003463_C1.png
# Timestamp of the image: 2020-02-07T15:12:20
# Timestamp from nav_data: 2020-02-07T15:12:20.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207151241_003520_C1.png
# Timestamp of the image: 2020-02-07T15:12:41
# Timestamp from nav_data: 2020-02-07T15:12:41.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207151245_003530_C1.png
# Timestamp of the image: 2020-02-07T15:12:45
# Timestamp from nav_data: 2020-02-07T15:12:45.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207151246_003533_C1.png
# Timestamp of the image: 2020-02-07T15:12:46
# Timestamp from nav_data: 2020-02-07T15:12:46.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207151253_003552_C1.png
# Timestamp of the image: 2020-02-07T15:12:53
# Timestamp from nav_data: 2020-02-07T15:12:53.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207151303_003583_C1.png
# Timestamp of the image: 2020-02-07T15:13:03
# Timestamp from nav_data: 2020-02-07T15:13:03.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207151304_003585_C1.png
# Timestamp of the image: 2020-02-07T15:13:04
# Timestamp from nav_data: 2020-02-07T15:13:04.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207151328_003656_C1.png
# Timestamp of the image: 2020-02-07T15:13:28
# Timestamp from nav_data: 2020-02-07T15:13:28.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207151357_003737_C1.png
# Timestamp of the image: 2020-02-07T15:13:57
# Timestamp from nav_data: 2020-02-07T15:13:57.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207151401_003748_C1.png
# Timestamp of the image: 2020-02-07T15:14:01
# Timestamp from nav_data: 2020-02-07T15:14:01.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207151405_003759_C1.png
# Timestamp of the image: 2020-02-07T15:14:05
# Timestamp from nav_data: 2020-02-07T15:14:05.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207151406_003761_C1.png
# Timestamp of the image: 2020-02-07T15:14:06
# Timestamp from nav_data: 2020-02-07T15:14:06.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207151440_003853_C1.png
# Timestamp of the image: 2020-02-07T15:14:40
# Timestamp from nav_data: 2020-02-07T15:14:40.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207151453_003890_C1.png
# Timestamp of the image: 2020-02-07T15:14:53
# Timestamp from nav_data: 2020-02-07T15:14:53.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207151519_003960_C1.png
# Timestamp of the image: 2020-02-07T15:15:19
# Timestamp from nav_data: 2020-02-07T15:15:19.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207151524_003974_C1.png
# Timestamp of the image: 2020-02-07T15:15:24
# Timestamp from nav_data: 2020-02-07T15:15:24.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207151533_004000_C1.png
# Timestamp of the image: 2020-02-07T15:15:33
# Timestamp from nav_data: 2020-02-07T15:15:33.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207151545_004032_C1.png
# Timestamp of the image: 2020-02-07T15:15:45
# Timestamp from nav_data: 2020-02-07T15:15:45.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207151549_004043_C1.png
# Timestamp of the image: 2020-02-07T15:15:49
# Timestamp from nav_data: 2020-02-07T15:15:49.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207151633_004161_C1.png
# Timestamp of the image: 2020-02-07T15:16:33
# Timestamp from nav_data: 2020-02-07T15:16:33.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207151822_004412_C1.png
# Timestamp of the image: 2020-02-07T15:18:22
# Timestamp from nav_data: 2020-02-07T15:18:22.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207151954_004623_C1.png
# Timestamp of the image: 2020-02-07T15:19:54
# Timestamp from nav_data: 2020-02-07T15:19:54.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207152036_004720_C1.png
# Timestamp of the image: 2020-02-07T15:20:36
# Timestamp from nav_data: 2020-02-07T15:20:36.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207152218_004923_C1.png
# Timestamp of the image: 2020-02-07T15:22:18
# Timestamp from nav_data: 2020-02-07T15:22:18.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207152301_005020_C1.png
# Timestamp of the image: 2020-02-07T15:23:01
# Timestamp from nav_data: 2020-02-07T15:23:01.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207152521_005379_C1.png
# Timestamp of the image: 2020-02-07T15:25:21
# Timestamp from nav_data: 2020-02-07T15:25:21.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207152529_005391_C1.png
# Timestamp of the image: 2020-02-07T15:25:29
# Timestamp from nav_data: 2020-02-07T15:25:29.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207152647_005593_C1.png
# Timestamp of the image: 2020-02-07T15:26:47
# Timestamp from nav_data: 2020-02-07T15:26:47.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207153103_005856_C1.png
# Timestamp of the image: 2020-02-07T15:31:03
# Timestamp from nav_data: 2020-02-07T15:31:03.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207153306_005980_C1.png
# Timestamp of the image: 2020-02-07T15:33:06
# Timestamp from nav_data: 2020-02-07T15:33:06.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20200207_1347_20200207153326_006031_C1.png
# Timestamp of the image: 2020-02-07T15:33:26
# Timestamp from nav_data: 2020-02-07T15:33:26.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20230123_1240_20230123132738_000086_C1.png
# Timestamp of the image: 2023-01-23T13:27:38
# Timestamp from nav_data: 2023-01-23T13:27:38.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20230123_1240_20230123135014_000809_C1.png
# Timestamp of the image: 2023-01-23T13:50:14
# Timestamp from nav_data: 2023-01-23T13:50:14.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20230123_1240_20230123140251_001134_C1.png
# Timestamp of the image: 2023-01-23T14:02:51
# Timestamp from nav_data: 2023-01-23T14:02:51.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20230123_1408_20230123143007_001234_C1.png
# Timestamp of the image: 2023-01-23T14:30:07
# Timestamp from nav_data: 2023-01-23T14:30:07.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20230123_1408_20230123143911_001457_C1.png
# Timestamp of the image: 2023-01-23T14:39:11
# Timestamp from nav_data: 2023-01-23T14:39:11.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20220217_1532_20220217202756_003752_C1.png
# Timestamp of the image: 2022-02-17T20:27:56
# Timestamp from nav_data: 2022-02-17T20:27:56.000000000
# Image array shape: (1024, 1360)
#
# Dendrites/IMPACTS_PHIPS_20220217_1532_20220217220140_005977_C1.png
# Timestamp of the image: 2022-02-17T22:01:40
# Timestamp from nav_data: 2022-02-17T22:01:40.000000000
# Image array shape: (1024, 1360)
#
# Extracting images for graupel...
# Graupel/IMPACTS_PHIPS_20200207_1347_20200207151305_003589_C1.png
# Timestamp of the image: 2020-02-07T15:13:05
# Timestamp from nav_data: 2020-02-07T15:13:05.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20200207_1347_20200207151349_003716_C1.png
# Timestamp of the image: 2020-02-07T15:13:49
# Timestamp from nav_data: 2020-02-07T15:13:49.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20200207_1347_20200207151846_004465_C1.png
# Timestamp of the image: 2020-02-07T15:18:46
# Timestamp from nav_data: 2020-02-07T15:18:46.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20200207_1347_20200207151907_004511_C1.png
# Timestamp of the image: 2020-02-07T15:19:07
# Timestamp from nav_data: 2020-02-07T15:19:07.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20200207_1347_20200207151911_004522_C1.png
# Timestamp of the image: 2020-02-07T15:19:11
# Timestamp from nav_data: 2020-02-07T15:19:11.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20200207_1347_20200207152022_004686_C1.png
# Timestamp of the image: 2020-02-07T15:20:22
# Timestamp from nav_data: 2020-02-07T15:20:22.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20200207_1347_20200207152027_004697_C1.png
# Timestamp of the image: 2020-02-07T15:20:27
# Timestamp from nav_data: 2020-02-07T15:20:27.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20200207_1347_20200207152027_004699_C1.png
# Timestamp of the image: 2020-02-07T15:20:27
# Timestamp from nav_data: 2020-02-07T15:20:27.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20200207_1347_20200207152040_004730_C1.png
# Timestamp of the image: 2020-02-07T15:20:40
# Timestamp from nav_data: 2020-02-07T15:20:40.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20200207_1347_20200207152044_004738_C1.png
# Timestamp of the image: 2020-02-07T15:20:44
# Timestamp from nav_data: 2020-02-07T15:20:44.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20200207_1347_20200207152107_004784_C1.png
# Timestamp of the image: 2020-02-07T15:21:07
# Timestamp from nav_data: 2020-02-07T15:21:07.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20200207_1347_20200207152107_004785_C1.png
# Timestamp of the image: 2020-02-07T15:21:07
# Timestamp from nav_data: 2020-02-07T15:21:07.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20200207_1347_20200207152122_004809_C1.png
# Timestamp of the image: 2020-02-07T15:21:22
# Timestamp from nav_data: 2020-02-07T15:21:22.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20200207_1347_20200207152139_004846_C1.png
# Timestamp of the image: 2020-02-07T15:21:39
# Timestamp from nav_data: 2020-02-07T15:21:39.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20200207_1347_20200207152157_004878_C1.png
# Timestamp of the image: 2020-02-07T15:21:57
# Timestamp from nav_data: 2020-02-07T15:21:57.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20200207_1347_20200207152747_005706_C1.png
# Timestamp of the image: 2020-02-07T15:27:47
# Timestamp from nav_data: 2020-02-07T15:27:47.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20200207_1347_20200207152935_005741_C1.png
# Timestamp of the image: 2020-02-07T15:29:35
# Timestamp from nav_data: 2020-02-07T15:29:35.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20200207_1347_20200207153139_005875_C1.png
# Timestamp of the image: 2020-02-07T15:31:39
# Timestamp from nav_data: 2020-02-07T15:31:39.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20200207_1347_20200207153217_005895_C1.png
# Timestamp of the image: 2020-02-07T15:32:17
# Timestamp from nav_data: 2020-02-07T15:32:17.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20200207_1347_20200207153238_005918_C1.png
# Timestamp of the image: 2020-02-07T15:32:38
# Timestamp from nav_data: 2020-02-07T15:32:38.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20200207_1347_20200207153244_005931_C1.png
# Timestamp of the image: 2020-02-07T15:32:44
# Timestamp from nav_data: 2020-02-07T15:32:44.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20200207_1347_20200207153304_005975_C1.png
# Timestamp of the image: 2020-02-07T15:33:04
# Timestamp from nav_data: 2020-02-07T15:33:04.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20200207_1347_20200207153440_006187_C1.png
# Timestamp of the image: 2020-02-07T15:34:40
# Timestamp from nav_data: 2020-02-07T15:34:40.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20230214_2105_20230215000552_007040_C1.png
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20230123_1240_20230123124536_000002_C1.png
# Timestamp of the image: 2023-01-23T12:45:36
# Timestamp from nav_data: 2023-01-23T12:45:36.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20230123_1240_20230123140509_001215_C1.png
# Timestamp of the image: 2023-01-23T14:05:09
# Timestamp from nav_data: 2023-01-23T14:05:09.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20230123_1408_20230123175211_012857_C1.png
# Timestamp of the image: 2023-01-23T17:52:11
# Timestamp from nav_data: 2023-01-23T17:52:11.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20220217_1532_20220217222144_006167_C1.png
# Timestamp of the image: 2022-02-17T22:21:44
# Timestamp from nav_data: 2022-02-17T22:21:44.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20230123_1408_20230123165547_009816_C1.png
# Timestamp of the image: 2023-01-23T16:55:47
# Timestamp from nav_data: 2023-01-23T16:55:47.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20230123_1408_20230123164422_009547_C1.png
# Timestamp of the image: 2023-01-23T16:44:22
# Timestamp from nav_data: 2023-01-23T16:44:22.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20230123_1408_20230123164423_009548_C1.png
# Timestamp of the image: 2023-01-23T16:44:23
# Timestamp from nav_data: 2023-01-23T16:44:23.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20230123_1408_20230123165246_009761_C1.png
# Timestamp of the image: 2023-01-23T16:52:46
# Timestamp from nav_data: 2023-01-23T16:52:46.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20230123_1408_20230123165535_009801_C1.png
# Timestamp of the image: 2023-01-23T16:55:35
# Timestamp from nav_data: 2023-01-23T16:55:35.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20230123_1408_20230123170115_010237_C1.png
# Timestamp of the image: 2023-01-23T17:01:15
# Timestamp from nav_data: 2023-01-23T17:01:15.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20230123_1408_20230123170453_010602_C1.png
# Timestamp of the image: 2023-01-23T17:04:53
# Timestamp from nav_data: 2023-01-23T17:04:53.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20230123_1408_20230123175721_013098_C1.png
# Timestamp of the image: 2023-01-23T17:57:21
# Timestamp from nav_data: 2023-01-23T17:57:21.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20230123_1408_20230123190535_013393_C1.png
# Timestamp of the image: 2023-01-23T19:05:35
# Timestamp from nav_data: 2023-01-23T19:05:35.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20220217_1532_20220217212046_005029_C1.png
# Timestamp of the image: 2022-02-17T21:20:46
# Timestamp from nav_data: 2022-02-17T21:20:46.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20220217_1532_20220217214959_005847_C1.png
# Timestamp of the image: 2022-02-17T21:49:59
# Timestamp from nav_data: 2022-02-17T21:49:59.000000000
# Image array shape: (1024, 1360)
#
# Graupel/IMPACTS_PHIPS_20220217_1532_20220217222112_006073_C1.png
# Timestamp of the image: 2022-02-17T22:21:12
# Timestamp from nav_data: 2022-02-17T22:21:12.000000000
# Image array shape: (1024, 1360)
#
# Extracting images for needles...
# Needles/IMPACTS_PHIPS_20230214_2105_20230215014841_010748_C1.png
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20230214_2105_20230215014848_010755_C1.png
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20230214_2105_20230215014848_010756_C1.png
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20230214_2105_20230215014854_010768_C1.png
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20230214_2105_20230215014855_010770_C1.png
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20230214_2105_20230215014857_010774_C1.png
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20230214_2105_20230215014857_010775_C1.png
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20230214_2105_20230215014859_010781_C1.png
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20230214_2105_20230215014903_010793_C1.png
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20230214_2105_20230215014906_010802_C1.png
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20230214_2105_20230215014907_010803_C1.png
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20230214_2105_20230215014909_010806_C1.png
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20230214_2105_20230215014909_010807_C1.png
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20230214_2105_20230215014914_010815_C1.png
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20230214_2105_20230215014914_010819_C1.png
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20230214_2105_20230215014915_010820_C1.png
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20230214_2105_20230215014917_010824_C1.png
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20230214_2105_20230215014917_010825_C1.png
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20230123_1408_20230123170953_010915_C1.png
# Timestamp of the image: 2023-01-23T17:09:53
# Timestamp from nav_data: 2023-01-23T17:09:53.000000000
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20230123_1408_20230123170951_010914_C1.png
# Timestamp of the image: 2023-01-23T17:09:51
# Timestamp from nav_data: 2023-01-23T17:09:51.000000000
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20230123_1408_20230123171018_010953_C1.png
# Timestamp of the image: 2023-01-23T17:10:18
# Timestamp from nav_data: 2023-01-23T17:10:18.000000000
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20230123_1408_20230123171030_010964_C1.png
# Timestamp of the image: 2023-01-23T17:10:30
# Timestamp from nav_data: 2023-01-23T17:10:30.000000000
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20230123_1408_20230123171030_010965_C1.png
# Timestamp of the image: 2023-01-23T17:10:30
# Timestamp from nav_data: 2023-01-23T17:10:30.000000000
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20230123_1408_20230123171035_010972_C1.png
# Timestamp of the image: 2023-01-23T17:10:35
# Timestamp from nav_data: 2023-01-23T17:10:35.000000000
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20230123_1408_20230123171053_010996_C1.png
# Timestamp of the image: 2023-01-23T17:10:53
# Timestamp from nav_data: 2023-01-23T17:10:53.000000000
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20230123_1408_20230123171059_011009_C1.png
# Timestamp of the image: 2023-01-23T17:10:59
# Timestamp from nav_data: 2023-01-23T17:10:59.000000000
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20230123_1408_20230123171153_011056_C1.png
# Timestamp of the image: 2023-01-23T17:11:53
# Timestamp from nav_data: 2023-01-23T17:11:53.000000000
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20230123_1408_20230123171153_011055_C1.png
# Timestamp of the image: 2023-01-23T17:11:53
# Timestamp from nav_data: 2023-01-23T17:11:53.000000000
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20230123_1408_20230123171255_011108_C1.png
# Timestamp of the image: 2023-01-23T17:12:55
# Timestamp from nav_data: 2023-01-23T17:12:55.000000000
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20230123_1408_20230123171407_011153_C1.png
# Timestamp of the image: 2023-01-23T17:14:07
# Timestamp from nav_data: 2023-01-23T17:14:07.000000000
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20220217_1532_20220217205513_004423_C1.png
# Timestamp of the image: 2022-02-17T20:55:13
# Timestamp from nav_data: 2022-02-17T20:55:13.000000000
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20220217_1532_20220217205521_004428_C1.png
# Timestamp of the image: 2022-02-17T20:55:21
# Timestamp from nav_data: 2022-02-17T20:55:21.000000000
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20220217_1532_20220217205524_004432_C1.png
# Timestamp of the image: 2022-02-17T20:55:24
# Timestamp from nav_data: 2022-02-17T20:55:24.000000000
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20220217_1532_20220217205530_004435_C1.png
# Timestamp of the image: 2022-02-17T20:55:30
# Timestamp from nav_data: 2022-02-17T20:55:30.000000000
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20220217_1532_20220217205737_004489_C1.png
# Timestamp of the image: 2022-02-17T20:57:37
# Timestamp from nav_data: 2022-02-17T20:57:37.000000000
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20220217_1532_20220217205742_004493_C1.png
# Timestamp of the image: 2022-02-17T20:57:42
# Timestamp from nav_data: 2022-02-17T20:57:42.000000000
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20220217_1532_20220217205854_004540_C1.png
# Timestamp of the image: 2022-02-17T20:58:54
# Timestamp from nav_data: 2022-02-17T20:58:54.000000000
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20220217_1532_20220217210216_004623_C1.png
# Timestamp of the image: 2022-02-17T21:02:16
# Timestamp from nav_data: 2022-02-17T21:02:16.000000000
# Image array shape: (1024, 1360)
#
# Needles/IMPACTS_PHIPS_20220217_1532_20220217210220_004626_C1.png
# Timestamp of the image: 2022-02-17T21:02:20
# Timestamp from nav_data: 2022-02-17T21:02:20.000000000
# Image array shape: (1024, 1360)
#
# ...
# Image array shape: (1024, 1360)
#
# Polycrystals/IMPACTS_PHIPS_20230123_1408_20230123173707_012049_C1.png
# Timestamp of the image: 2023-01-23T17:37:07
# Timestamp from nav_data: 2023-01-23T17:37:07.000000000
# Image array shape: (1024, 1360)
#
# Polycrystals/IMPACTS_PHIPS_20220217_1532_20220217201331_003284_C1.png
# Timestamp of the image: 2022-02-17T20:13:31
# Timestamp from nav_data: 2022-02-17T20:13:31.000000000
# Image array shape: (1024, 1360)
#
# Polycrystals/IMPACTS_PHIPS_20220217_1532_20220217203340_003875_C1.png
# Timestamp of the image: 2022-02-17T20:33:40
# Timestamp from nav_data: 2022-02-17T20:33:40.000000000
# Image array shape: (1024, 1360)
#
# Polycrystals/IMPACTS_PHIPS_20220217_1532_20220217203404_003886_C1.png
# Timestamp of the image: 2022-02-17T20:34:04
# Timestamp from nav_data: 2022-02-17T20:34:04.000000000
# Image array shape: (1024, 1360)
#
# Polycrystals/IMPACTS_PHIPS_20220217_1532_20220217204034_004007_C1.png
# Timestamp of the image: 2022-02-17T20:40:34
# Timestamp from nav_data: 2022-02-17T20:40:34.000000000
# Image array shape: (1024, 1360)
#
# Polycrystals/IMPACTS_PHIPS_20220217_1532_20220217214245_005683_C1.png
# Timestamp of the image: 2022-02-17T21:42:45
# Timestamp from nav_data: 2022-02-17T21:42:45.000000000
# Image array shape: (1024, 1360)
#
# Polycrystals/IMPACTS_PHIPS_20220217_1532_20220217214340_005699_C1.png
# Timestamp of the image: 2022-02-17T21:43:40
# Timestamp from nav_data: 2022-02-17T21:43:40.000000000
# Image array shape: (1024, 1360)
#
# Polycrystals/IMPACTS_PHIPS_20220217_1532_20220217214401_005715_C1.png
# Timestamp of the image: 2022-02-17T21:44:01
# Timestamp from nav_data: 2022-02-17T21:44:01.000000000
# Image array shape: (1024, 1360)
#
# Polycrystals/IMPACTS_PHIPS_20230123_1408_20230123142524_000778_C1.png
# Timestamp of the image: 2023-01-23T14:25:24
# Timestamp from nav_data: 2023-01-23T14:25:24.000000000
# Image array shape: (1024, 1360)
#
# Polycrystals/IMPACTS_PHIPS_20230123_1408_20230123142638_000937_C1.png
# Timestamp of the image: 2023-01-23T14:26:38
# Timestamp from nav_data: 2023-01-23T14:26:38.000000000
# Image array shape: (1024, 1360)
#
# Polycrystals/IMPACTS_PHIPS_20230123_1408_20230123144223_001549_C1.png
# Timestamp of the image: 2023-01-23T14:42:23
# Timestamp from nav_data: 2023-01-23T14:42:23.000000000
# Image array shape: (1024, 1360)
#
# Polycrystals/IMPACTS_PHIPS_20230123_1408_20230123144227_001567_C1.png
# Timestamp of the image: 2023-01-23T14:42:27
# Timestamp from nav_data: 2023-01-23T14:42:27.000000000
# Image array shape: (1024, 1360)
#
# Extracting images for side_planes...
# Side-planes/IMPACTS_PHIPS_20200207_1347_20200207151038_003179_C1.png
# Timestamp of the image: 2020-02-07T15:10:38
# Timestamp from nav_data: 2020-02-07T15:10:38.000000000
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20200207_1347_20200207151048_003207_C1.png
# Timestamp of the image: 2020-02-07T15:10:48
# Timestamp from nav_data: 2020-02-07T15:10:48.000000000
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20200207_1347_20200207151056_003230_C1.png
# Timestamp of the image: 2020-02-07T15:10:56
# Timestamp from nav_data: 2020-02-07T15:10:56.000000000
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20200207_1347_20200207151106_003256_C1.png
# Timestamp of the image: 2020-02-07T15:11:06
# Timestamp from nav_data: 2020-02-07T15:11:06.000000000
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20200207_1347_20200207151259_003570_C1.png
# Timestamp of the image: 2020-02-07T15:12:59
# Timestamp from nav_data: 2020-02-07T15:12:59.000000000
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20200207_1347_20200207151405_003758_C1.png
# Timestamp of the image: 2020-02-07T15:14:05
# Timestamp from nav_data: 2020-02-07T15:14:05.000000000
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20200207_1347_20200207152249_004988_C1.png
# Timestamp of the image: 2020-02-07T15:22:49
# Timestamp from nav_data: 2020-02-07T15:22:49.000000000
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20200207_1347_20200207152558_005459_C1.png
# Timestamp of the image: 2020-02-07T15:25:58
# Timestamp from nav_data: 2020-02-07T15:25:58.000000000
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20200207_1347_20200207164552_016263_C1.png
# Timestamp of the image: 2020-02-07T16:45:52
# Timestamp from nav_data: 2020-02-07T16:45:52.000000000
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20200207_1347_20200207164554_016266_C1.png
# Timestamp of the image: 2020-02-07T16:45:54
# Timestamp from nav_data: 2020-02-07T16:45:54.000000000
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20200207_1347_20200207164644_016345_C1.png
# Timestamp of the image: 2020-02-07T16:46:44
# Timestamp from nav_data: 2020-02-07T16:46:44.000000000
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20200207_1347_20200207164659_016375_C1.png
# Timestamp of the image: 2020-02-07T16:46:59
# Timestamp from nav_data: 2020-02-07T16:46:59.000000000
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20200207_1347_20200207164745_016463_C1.png
# Timestamp of the image: 2020-02-07T16:47:45
# Timestamp from nav_data: 2020-02-07T16:47:45.000000000
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20200207_1347_20200207165252_017083_C1.png
# Timestamp of the image: 2020-02-07T16:52:52
# Timestamp from nav_data: 2020-02-07T16:52:52.000000000
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20200207_1347_20200207165717_017720_C1.png
# Timestamp of the image: 2020-02-07T16:57:17
# Timestamp from nav_data: 2020-02-07T16:57:17.000000000
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20200207_1347_20200207165722_017733_C1.png
# Timestamp of the image: 2020-02-07T16:57:22
# Timestamp from nav_data: 2020-02-07T16:57:22.000000000
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20200207_1347_20200207165727_017746_C1.png
# Timestamp of the image: 2020-02-07T16:57:27
# Timestamp from nav_data: 2020-02-07T16:57:27.000000000
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20200207_1347_20200207165856_017959_C1.png
# Timestamp of the image: 2020-02-07T16:58:56
# Timestamp from nav_data: 2020-02-07T16:58:56.000000000
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20200207_1347_20200207164738_016448_C1.png
# Timestamp of the image: 2020-02-07T16:47:38
# Timestamp from nav_data: 2020-02-07T16:47:38.000000000
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20200207_1347_20200207165914_018002_C1.png
# Timestamp of the image: 2020-02-07T16:59:14
# Timestamp from nav_data: 2020-02-07T16:59:14.000000000
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20200207_1347_20200207165945_018073_C1.png
# Timestamp of the image: 2020-02-07T16:59:45
# Timestamp from nav_data: 2020-02-07T16:59:45.000000000
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20230214_2105_20230215000042_006927_C1.png
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20230214_2105_20230215000353_006993_C1.png
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20230214_2105_20230215000402_007001_C1.png
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20230214_2105_20230215000924_007102_C1.png
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20230214_2105_20230215000931_007110_C1.png
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20230214_2105_20230215004341_008109_C1.png
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20230214_2105_20230215004603_008168_C1.png
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20230214_2105_20230215004901_008207_C1.png
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20230214_2105_20230215004946_008227_C1.png
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20230214_2105_20230215005045_008244_C1.png
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20230214_2105_20230215005245_008297_C1.png
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20230214_2105_20230215005254_008303_C1.png
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20230214_2105_20230215005301_008307_C1.png
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20230214_2105_20230215005312_008315_C1.png
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20230214_2105_20230215005334_008339_C1.png
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20230214_2105_20230215005335_008340_C1.png
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20230214_2105_20230215005351_008356_C1.png
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20230123_1408_20230123175231_012888_C1.png
# Timestamp of the image: 2023-01-23T17:52:31
# Timestamp from nav_data: 2023-01-23T17:52:31.000000000
# Image array shape: (1024, 1360)
#
# Side-planes/IMPACTS_PHIPS_20230123_1408_20230123190637_013418_C1.png
# Timestamp of the image: 2023-01-23T19:06:37
# Timestamp from nav_data: 2023-01-23T19:06:37.000000000
# Image array shape: (1024, 1360)
#
# Extracting images for tiny...
# Tiny/IMPACTS_PHIPS_20200207_1347_20200207152746_005703_C1.png
# Timestamp of the image: 2020-02-07T15:27:46
# Timestamp from nav_data: 2020-02-07T15:27:46.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20200207_1347_20200207152745_005701_C1.png
# Timestamp of the image: 2020-02-07T15:27:45
# Timestamp from nav_data: 2020-02-07T15:27:45.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20200207_1347_20200207152741_005697_C1.png
# Timestamp of the image: 2020-02-07T15:27:41
# Timestamp from nav_data: 2020-02-07T15:27:41.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20200207_1347_20200207152747_005705_C1.png
# Timestamp of the image: 2020-02-07T15:27:47
# Timestamp from nav_data: 2020-02-07T15:27:47.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20200207_1347_20200207152940_005750_C1.png
# Timestamp of the image: 2020-02-07T15:29:40
# Timestamp from nav_data: 2020-02-07T15:29:40.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20200207_1347_20200207152949_005766_C1.png
# Timestamp of the image: 2020-02-07T15:29:49
# Timestamp from nav_data: 2020-02-07T15:29:49.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20200207_1347_20200207153000_005781_C1.png
# Timestamp of the image: 2020-02-07T15:30:00
# Timestamp from nav_data: 2020-02-07T15:30:00.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20230123_1408_20230123165622_009875_C1.png
# Timestamp of the image: 2023-01-23T16:56:22
# Timestamp from nav_data: 2023-01-23T16:56:22.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20200207_1347_20200207153419_006137_C1.png
# Timestamp of the image: 2020-02-07T15:34:19
# Timestamp from nav_data: 2020-02-07T15:34:19.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20200207_1347_20200207153421_006140_C1.png
# Timestamp of the image: 2020-02-07T15:34:21
# Timestamp from nav_data: 2020-02-07T15:34:21.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20200207_1347_20200207153425_006152_C1.png
# Timestamp of the image: 2020-02-07T15:34:25
# Timestamp from nav_data: 2020-02-07T15:34:25.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20200207_1347_20200207153435_006174_C1.png
# Timestamp of the image: 2020-02-07T15:34:35
# Timestamp from nav_data: 2020-02-07T15:34:35.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20230123_1408_20230123173724_012105_C1.png
# Timestamp of the image: 2023-01-23T17:37:24
# Timestamp from nav_data: 2023-01-23T17:37:24.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20230123_1408_20230123173814_012260_C1.png
# Timestamp of the image: 2023-01-23T17:38:14
# Timestamp from nav_data: 2023-01-23T17:38:14.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20230123_1408_20230123173839_012292_C1.png
# Timestamp of the image: 2023-01-23T17:38:39
# Timestamp from nav_data: 2023-01-23T17:38:39.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20230123_1408_20230123174805_012371_C1.png
# Timestamp of the image: 2023-01-23T17:48:05
# Timestamp from nav_data: 2023-01-23T17:48:05.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20200207_1347_20200207153448_006209_C1.png
# Timestamp of the image: 2020-02-07T15:34:48
# Timestamp from nav_data: 2020-02-07T15:34:48.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20230123_1408_20230123174818_012400_C1.png
# Timestamp of the image: 2023-01-23T17:48:18
# Timestamp from nav_data: 2023-01-23T17:48:18.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20230123_1408_20230123174927_012536_C1.png
# Timestamp of the image: 2023-01-23T17:49:27
# Timestamp from nav_data: 2023-01-23T17:49:27.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20230123_1408_20230123175018_012618_C1.png
# Timestamp of the image: 2023-01-23T17:50:18
# Timestamp from nav_data: 2023-01-23T17:50:18.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20230123_1408_20230123175040_012688_C1.png
# Timestamp of the image: 2023-01-23T17:50:40
# Timestamp from nav_data: 2023-01-23T17:50:40.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20230123_1408_20230123175044_012696_C1.png
# Timestamp of the image: 2023-01-23T17:50:44
# Timestamp from nav_data: 2023-01-23T17:50:44.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20230123_1408_20230123175106_012739_C1.png
# Timestamp of the image: 2023-01-23T17:51:06
# Timestamp from nav_data: 2023-01-23T17:51:06.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20230123_1408_20230123175127_012770_C1.png
# Timestamp of the image: 2023-01-23T17:51:27
# Timestamp from nav_data: 2023-01-23T17:51:27.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20220217_1532_20220217192356_002299_C1.png
# Timestamp of the image: 2022-02-17T19:23:56
# Timestamp from nav_data: 2022-02-17T19:23:56.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20220217_1532_20220217193003_002441_C1.png
# Timestamp of the image: 2022-02-17T19:30:03
# Timestamp from nav_data: 2022-02-17T19:30:03.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20220217_1532_20220217201322_003281_C1.png
# Timestamp of the image: 2022-02-17T20:13:22
# Timestamp from nav_data: 2022-02-17T20:13:22.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20220217_1532_20220217201441_003325_C1.png
# Timestamp of the image: 2022-02-17T20:14:41
# Timestamp from nav_data: 2022-02-17T20:14:41.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20220217_1532_20220217203531_003914_C1.png
# Timestamp of the image: 2022-02-17T20:35:31
# Timestamp from nav_data: 2022-02-17T20:35:31.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20220217_1532_20220217212001_005010_C1.png
# Timestamp of the image: 2022-02-17T21:20:01
# Timestamp from nav_data: 2022-02-17T21:20:01.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20230214_2105_20230215011850_009537_C1.png
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20230214_2105_20230215014857_010776_C1.png
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20230214_2105_20230215020835_011552_C1.png
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20230214_2105_20230215020857_011569_C1.png
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20230214_2105_20230215025118_012248_C1.png
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20230214_2105_20230215025135_012255_C1.png
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20230214_2105_20230215030403_012566_C1.png
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20230123_1408_20230123165039_009705_C1.png
# Timestamp of the image: 2023-01-23T16:50:39
# Timestamp from nav_data: 2023-01-23T16:50:39.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20230123_1408_20230123165554_009827_C1.png
# Timestamp of the image: 2023-01-23T16:55:54
# Timestamp from nav_data: 2023-01-23T16:55:54.000000000
# Image array shape: (1024, 1360)
#
# Tiny/IMPACTS_PHIPS_20230123_1408_20230123165754_009962_C1.png
# Timestamp of the image: 2023-01-23T16:57:54
# Timestamp from nav_data: 2023-01-23T16:57:54.000000000
# Image array shape: (1024, 1360)

# %%
print("Number of dataset entries:", len(dataset_entries))
print("Sample dataset entry:", dataset_entries[0])
# Out:
# Number of dataset entries: 440
# Sample dataset entry: {'image_array': array([[204, 201, 198, ...,  88,  75,  71],
#        [206, 203, 200, ...,  94,  80,  71],
#        [206, 206, 202, ...,  97,  88,  71],
#        ...,
#        [255, 254, 249, ..., 126, 122, 115],
#        [255, 255, 249, ..., 135, 123, 115],
#        [255, 255, 249, ..., 136, 124, 117]], dtype=uint8), 'timestamp': '2020-02-07T15:10:36', 'label': 'aggregate', 'latitude': array(43.124961), 'longitude': array(43.124961), 'temperature': -15.21, 'altitude': 5.147}

# %%
# Define lists to hold dataset entries
image_arrays = []
timestamps = []
labels = []
latitudes = []
longitudes = []
temperatures = []
altitudes = []

# Iterate over dataset_entries to fill arrays/lists
for entry in dataset_entries:
    # Append the image array and other attributes to lists
    image_arrays.append(entry['image_array'])  # Keep the original shape
    timestamps.append(entry['timestamp'])
    labels.append(entry['label'])
    latitudes.append(entry['latitude'])
    longitudes.append(entry['longitude'])
    temperatures.append(entry['temperature'])
    altitudes.append(entry['altitude'])

# Convert lists to numpy arrays
image_arrays = np.array(image_arrays)  # Shape will be (samples, height, width)
timestamps = np.array(timestamps)
labels = np.array(labels)
latitudes = np.array(latitudes)
longitudes = np.array(longitudes)
temperatures = np.array(temperatures)
altitudes = np.array(altitudes)


# Create an Xarray dataset
ds = xr.Dataset(
    {
        'image_array': (['samples', 'height', 'width'], image_arrays),  # Use 3D shape (samples, height, width)
        'timestamp': ('samples', timestamps),
        'label': ('samples', labels),
        'latitude': ('samples', latitudes),
        'longitude': ('samples', longitudes),
        'temperature': ('samples', temperatures),
        'altitude': ('samples', altitudes),
    },
    coords={
        'samples': np.arange(len(dataset_entries)),  # Coordinate for the samples
    }
)

# Adding global attributes
ds.attrs['description'] = 'AI-ready dataset for ice crystal habit classification in high-resolution images taken by the PHIPS instrument during the NASA IMPACTS field campaign.'
ds.attrs['creation_date'] = '2024-10-24'
ds.attrs['author'] = 'Valeria Garcia (vgarcia1@uw.edu)'

# Adding attributes to a specific variable
ds['image_array'].attrs['units'] = 'pixel values'
ds['latitude'].attrs['units'] = 'degrees_north'
ds['longitude'].attrs['units'] = 'degrees_east'
ds['temperature'].attrs['units'] = 'Celsius'
ds['altitude'].attrs['units'] = 'kilometers'

# %%
# Print the dataset to check its structure
print(ds)
# Out:
# <xarray.Dataset>
# Dimensions:      (samples: 440, height: 1024, width: 1360)
# Coordinates:
#   * samples      (samples) int64 0 1 2 3 4 5 6 7 ... 433 434 435 436 437 438 439
# Dimensions without coordinates: height, width
# Data variables:
#     image_array  (samples, height, width) uint8 204 201 198 192 ... 157 157 156
#     timestamp    (samples) <U19 '2020-02-07T15:10:36' ... '2023-01-23T16:57:54'
#     label        (samples) <U14 'aggregate' 'aggregate' ... 'tiny' 'tiny'
#     latitude     (samples) float64 43.12 43.12 43.12 43.12 ... 44.84 44.79 44.65
#     longitude    (samples) float64 43.12 43.12 43.12 43.12 ... 44.84 44.79 44.65
#     temperature  (samples) float64 -15.21 -15.28 -15.25 ... -13.14 -5.29 -5.31
#     altitude     (samples) float64 5.147 5.147 5.147 5.147 ... 3.967 2.674 2.686
# Attributes:
#     description:    AI-ready dataset for ice crystal habit classification in ...
#     creation_date:  2024-10-24
#     author:         Valeria Garcia (vgarcia1@uw.edu)

# %%
# Save the dataset to a NetCDF file (outside of GitHub repo since the file size exceeds the Github limit)
ds.to_netcdf('/home/disk/meso-home/vgarcia1/PHIPS_classification/PHIPS_CrystalHabitAI_Dataset.nc')

# %% [markdown]
# ## PHIPS Crystal Habit AI-Ready Dataset
#
# #### Size of NetCDF file: 584.4 MB
#
# #### Note: Due to the size of the dataset exceeding 100 MB, it cannot be directly uploaded to Github in data/ai_ready. Instead, the file was downloaded locally and shared on Google Drive. The dataset can be downloaded automatically by clicking this link: https://drive.google.com/uc?id=1gnfZpiBP954-qddiRfEZInfuAoMI7Y__
#
# #### The dataset contains the following variables:
#
#
# - `image_array`: A 3D array of greyscale images with dimensions `(samples, height, width)`. Each entry represents a 2D array of pixel intensities for an image.
# - `timestamp`: The timestamp for each ice crystal image in ISO format (`YYYY-MM-DDTHH:MM:SS`), indicating the time it was captured during a flight.
# - `label`: The classified habit type of the ice crystal, with labels in singular form (e.g., 'aggregate', 'column').
# - `latitude`: The geographic latitude coordinate where the image was captured.
# - `longitude`: The geographic longitude coordinate where the image was captured.
# - `temperature`: The air temperature (in degrees Celsius) at the time and location corresponding to each image.
# - `altitude`: The flight altitude in kilometers at the time the image was captured.
#
# #### This dataset contains a total of 440 samples of various ice crystals images imaged during the NASA IMPACTS deployments (on flights 2020-02-07, 2022-02-17, 2023-01-23, or 2023-02-14), each converted to numpy array. All images are in greyscale and equally sized (1024 Height x 1360 Width pixels). Each image is labeled with one of 11 ice crystal habit categories (aggregate, bullet-rosette, capped column, column, dendrite, graupel, meedle, plate, polycrystal, side-plane, tiny), with 40 images labeled per category.
